# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhTuan1807/BTVN/blob/main/Nhan_dien_tien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Khai bao cac thu vien can su dung
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Ket noi voi google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Tao ra class ImageDataGenerator de chinh sua anh 
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Tien/Train', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 2462 images belonging to 11 classes.

# %%
# Tao bo du lieu test
test_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Tien/Test', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 1056 images belonging to 11 classes.

# %%
# Cac nhan co trong bo du lieu training
training_set.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
# Cac nhan co trong bo du lieu test
test_set.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
x_train = np.concatenate([training_set.next()[0] for i in range(training_set.__len__())])
y_train = np.concatenate([training_set.next()[1] for i in range(training_set.__len__())])
print(x_train.shape)
print(y_train.shape)
# Out:
# (2462, 224, 224, 3)
# (2462, 11)

# %%
x_test = np.concatenate([test_set.next()[0] for i in range(test_set.__len__())])
y_test = np.concatenate([test_set.next()[1] for i in range(test_set.__len__())])
print(x_test.shape)
print(y_test.shape)
# Out:
# (1056, 224, 224, 3)
# (1056, 11)

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation="relu", input_shape=(224,224,3), padding="same"))
model.add(MaxPooling2D((2,2), padding="same"))
model.add(Conv2D(64, kernel_size=(3,3), activation="relu", padding="same"))
model.add(MaxPooling2D((2,2), padding="same"))
model.add(Conv2D(128, kernel_size=(3,3), activation="relu", padding="same"))
model.add(MaxPooling2D((2,2), padding="same"))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(11, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 128)               12845184
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 12,939,851
# Trainable params: 12,939,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

# %%
history = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 77/77 - 13s - loss: 2.5336 - accuracy: 0.0967 - 13s/epoch - 173ms/step
# Epoch 2/100
# 77/77 - 4s - loss: 2.3845 - accuracy: 0.0938 - 4s/epoch - 53ms/step
# Epoch 3/100
# 77/77 - 4s - loss: 2.3751 - accuracy: 0.1206 - 4s/epoch - 53ms/step
# Epoch 4/100
# 77/77 - 4s - loss: 2.3388 - accuracy: 0.1572 - 4s/epoch - 53ms/step
# Epoch 5/100
# 77/77 - 4s - loss: 2.2119 - accuracy: 0.2206 - 4s/epoch - 53ms/step
# Epoch 6/100
# 77/77 - 4s - loss: 1.8898 - accuracy: 0.3599 - 4s/epoch - 53ms/step
# Epoch 7/100
# 77/77 - 4s - loss: 1.2657 - accuracy: 0.5804 - 4s/epoch - 53ms/step
# Epoch 8/100
# 77/77 - 4s - loss: 0.5518 - accuracy: 0.8229 - 4s/epoch - 53ms/step
# Epoch 9/100
# 77/77 - 4s - loss: 0.1934 - accuracy: 0.9460 - 4s/epoch - 53ms/step
# Epoch 10/100
# 77/77 - 4s - loss: 0.1028 - accuracy: 0.9797 - 4s/epoch - 53ms/step
# Epoch 11/100
# 77/77 - 4s - loss: 0.0644 - accuracy: 0.9903 - 4s/epoch - 54ms/step
-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 67/100
# 77/77 - 4s - loss: 6.0513e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 68/100
# 77/77 - 4s - loss: 5.7474e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 69/100
# 77/77 - 4s - loss: 5.4552e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 70/100
# 77/77 - 4s - loss: 5.1840e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 71/100
# 77/77 - 4s - loss: 4.9294e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 72/100
# 77/77 - 4s - loss: 4.6863e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 73/100
# 77/77 - 4s - loss: 4.4585e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 74/100
# 77/77 - 4s - loss: 4.2409e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 75/100
# 77/77 - 4s - loss: 4.0313e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 76/100
# 77/77 - 4s - loss: 3.8348e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 77/100
# 77/77 - 4s - loss: 3.6513e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 78/100
# 77/77 - 4s - loss: 3.4745e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 79/100
# 77/77 - 4s - loss: 3.3100e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 80/100
# 77/77 - 4s - loss: 3.1475e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 81/100
# 77/77 - 4s - loss: 2.9991e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 82/100
# 77/77 - 4s - loss: 2.8549e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 83/100
# 77/77 - 4s - loss: 2.7186e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 84/100
# 77/77 - 4s - loss: 2.5901e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 85/100
# 77/77 - 4s - loss: 2.4704e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 86/100
# 77/77 - 4s - loss: 2.3500e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 87/100
# 77/77 - 4s - loss: 2.2409e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 88/100
# 77/77 - 4s - loss: 2.1327e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 89/100
# 77/77 - 4s - loss: 2.0326e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 90/100
# 77/77 - 4s - loss: 1.9375e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 91/100
# 77/77 - 4s - loss: 1.8471e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 92/100
# 77/77 - 4s - loss: 1.7593e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 93/100
# 77/77 - 4s - loss: 1.6748e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 94/100
# 77/77 - 4s - loss: 1.5971e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 95/100
# 77/77 - 4s - loss: 1.5162e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 96/100
# 77/77 - 4s - loss: 1.4393e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 97/100
# 77/77 - 4s - loss: 1.3701e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 98/100
# 77/77 - 4s - loss: 1.3043e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 99/100
# 77/77 - 4s - loss: 1.2407e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 100/100
# 77/77 - 4s - loss: 1.1781e-06 - accuracy: 1.0000 - 4s/epoch - 55ms/step

# %%
# Danh gia ve do chinh xac cua mo hinh 
Score=model.evaluate(x_train,y_train,verbose=2)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# 77/77 - 2s - loss: 1.1361e-06 - accuracy: 1.0000 - 2s/epoch - 28ms/step
# Train Loss 1.1361156566636055e-06
# Train Accuracy 1.0

# %%
# Ve do thi giua sai so (Loss) va do chinh xac (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Luu lai
model.save("Nhan_dien_tien.h5")

# %%
# Tai mo hinh
model_ANN=load_model('Nhan_dien_tien.h5')

# %%
class_names = ["200", "500", "1000","2000","5000","10000","20000","50000","100000","200000","500000"]

# %%
from tensorflow.keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np

url = "/content/drive/MyDrive/Tien/Test/100000/100000_13.png"
img = load_img(url, target_size=(224,224,3))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 224,224,3)
img = img.astype("float32")
img = img/255
img = img.reshape(-1, 224,224,3)

prediction = model.predict(img)
np.argmax(prediction, axis=1)
index = -1
max_value = -1

for i in range(0, len(prediction[0])):
  if max_value < prediction[0][i]:
    max_value = prediction[0][i]
    index = i
print(prediction)
print("Kết quả: ", class_names[index])
print("Độ chính xác: ", max_value)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[2.3196098e-01 2.9289410e-07 5.2747441e-07 1.7187649e-10 1.7953053e-07
#   1.0076492e-04 4.0280273e-07 1.3866188e-04 7.6775998e-01 3.8173821e-05
#   1.0755111e-08]]
# Kết quả:  100000
# Độ chính xác:  0.76776
