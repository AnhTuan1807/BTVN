# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhTuan1807/BTVN/blob/main/Nhan_dien_tien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Khai bao cac thu vien can su dung
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Ket noi voi google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Tao ra class ImageDataGenerator de chinh sua anh 
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Tien/Train', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 2462 images belonging to 11 classes.

# %%
# Tao bo du lieu test
test_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Tien/Test', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 1056 images belonging to 11 classes.

# %%
# Cac nhan co trong bo du lieu training
training_set.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
# Cac nhan co trong bo du lieu test
test_set.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
x_train = np.concatenate([training_set.next()[0] for i in range(training_set.__len__())])
y_train = np.concatenate([training_set.next()[1] for i in range(training_set.__len__())])
print(x_train.shape)
print(y_train.shape)
# Out:
# (2462, 224, 224, 3)
# (2462, 11)

# %%
x_test = np.concatenate([test_set.next()[0] for i in range(test_set.__len__())])
y_test = np.concatenate([test_set.next()[1] for i in range(test_set.__len__())])
print(x_test.shape)
print(y_test.shape)
# Out:
# (1056, 224, 224, 3)
# (1056, 11)

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation="relu", input_shape=(224,224,3), padding="same"))
model.add(MaxPooling2D((2,2), padding="same"))
model.add(Conv2D(64, kernel_size=(3,3), activation="relu", padding="same"))
model.add(MaxPooling2D((2,2), padding="same"))
model.add(Conv2D(128, kernel_size=(3,3), activation="relu", padding="same"))
model.add(MaxPooling2D((2,2), padding="same"))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(11, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 224, 224, 32)      896
#
#  max_pooling2d_9 (MaxPooling  (None, 112, 112, 32)     0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 112, 112, 64)      18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 56, 56, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 56, 56, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 28, 28, 128)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 100352)            0
#
#  dense_6 (Dense)             (None, 128)               12845184
#
#  dense_7 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 12,939,851
# Trainable params: 12,939,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

# %%
history = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 77/77 - 5s - loss: 2.4637 - accuracy: 0.1056 - 5s/epoch - 61ms/step
# Epoch 2/100
# 77/77 - 4s - loss: 2.3892 - accuracy: 0.1003 - 4s/epoch - 53ms/step
# Epoch 3/100
# 77/77 - 4s - loss: 2.3866 - accuracy: 0.1105 - 4s/epoch - 54ms/step
# Epoch 4/100
# 77/77 - 4s - loss: 2.3766 - accuracy: 0.1170 - 4s/epoch - 54ms/step
# Epoch 5/100
# 77/77 - 4s - loss: 2.3423 - accuracy: 0.1608 - 4s/epoch - 54ms/step
# Epoch 6/100
# 77/77 - 4s - loss: 2.2233 - accuracy: 0.2254 - 4s/epoch - 54ms/step
# Epoch 7/100
# 77/77 - 4s - loss: 1.8621 - accuracy: 0.3635 - 4s/epoch - 55ms/step
# Epoch 8/100
# 77/77 - 4s - loss: 1.1807 - accuracy: 0.6194 - 4s/epoch - 55ms/step
# Epoch 9/100
# 77/77 - 4s - loss: 0.5434 - accuracy: 0.8278 - 4s/epoch - 55ms/step
# Epoch 10/100
# 77/77 - 4s - loss: 0.1570 - accuracy: 0.9574 - 4s/epoch - 55ms/step
-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 68/100
# 77/77 - 4s - loss: 2.3760e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 69/100
# 77/77 - 4s - loss: 2.2351e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 70/100
# 77/77 - 4s - loss: 2.1397e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 71/100
# 77/77 - 4s - loss: 2.0331e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 72/100
# 77/77 - 4s - loss: 1.9184e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 73/100
# 77/77 - 4s - loss: 1.8380e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 74/100
# 77/77 - 4s - loss: 1.7528e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 75/100
# 77/77 - 4s - loss: 1.6671e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 76/100
# 77/77 - 4s - loss: 1.5978e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 77/100
# 77/77 - 4s - loss: 1.5223e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 78/100
# 77/77 - 4s - loss: 1.4540e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 79/100
# 77/77 - 4s - loss: 1.4047e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 80/100
# 77/77 - 4s - loss: 1.3364e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 81/100
# 77/77 - 4s - loss: 1.2788e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 82/100
# 77/77 - 4s - loss: 1.2153e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 83/100
# 77/77 - 4s - loss: 1.1756e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 84/100
# 77/77 - 4s - loss: 1.1078e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 85/100
# 77/77 - 4s - loss: 1.0706e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 86/100
# 77/77 - 4s - loss: 1.0236e-07 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 87/100
# 77/77 - 4s - loss: 9.8389e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 88/100
# 77/77 - 4s - loss: 9.3353e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 89/100
# 77/77 - 4s - loss: 9.1223e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 90/100
# 77/77 - 4s - loss: 8.6381e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 91/100
# 77/77 - 4s - loss: 8.4347e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 92/100
# 77/77 - 4s - loss: 7.8973e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 93/100
# 77/77 - 4s - loss: 7.7617e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 94/100
# 77/77 - 4s - loss: 7.3307e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 95/100
# 77/77 - 4s - loss: 7.1032e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 96/100
# 77/77 - 4s - loss: 6.9337e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 97/100
# 77/77 - 4s - loss: 6.6141e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 98/100
# 77/77 - 4s - loss: 6.3285e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 99/100
# 77/77 - 4s - loss: 6.0767e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step
# Epoch 100/100
# 77/77 - 4s - loss: 5.8394e-08 - accuracy: 1.0000 - 4s/epoch - 55ms/step

# %%
# Danh gia ve do chinh xac cua mo hinh 
Score=model.evaluate(x_train,y_train,verbose=2)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# 77/77 - 2s - loss: 5.4714e-08 - accuracy: 1.0000 - 2s/epoch - 28ms/step
# Train Loss 5.4714249131393444e-08
# Train Accuracy 1.0

# %%
# Ve do thi giua sai so (Loss) va do chinh xac (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Luu lai
model.save("Nhan_dien_tien.h5")

# %%
# Tai mo hinh
model_ANN=load_model('Nhan_dien_tien.h5')

# %%
class_names = ["200", "500", "1000","2000","5000","10000","20000","50000","100000","200000","500000"]

# %%
from tensorflow.keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np

url = "/content/drive/MyDrive/Tien/Test/100000/100000_137.png"
img = load_img(url, target_size=(224,224,3))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 224,224,3)
img = img.astype("float32")
img = img/255
img = img.reshape(-1, 224,224,3)

prediction = model.predict(img)
np.argmax(prediction, axis=1)
index = -1
max_value = -1

for i in range(0, len(prediction[0])):
  if max_value < prediction[0][i]:
    max_value = prediction[0][i]
    index = i
print(prediction)
print("Kết quả: ", class_names[index])
print("Độ chính xác: ", max_value)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[1.6073214e-10 7.9993017e-02 3.1014250e-04 1.6487520e-14 1.6444802e-11
#   1.2394925e-05 3.6345106e-02 1.0733743e-06 8.2785279e-01 7.0794222e-08
#   5.5485398e-02]]
# Kết quả:  100000
# Độ chính xác:  0.8278528
